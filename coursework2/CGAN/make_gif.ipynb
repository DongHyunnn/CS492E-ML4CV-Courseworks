# %%
import glob
from PIL import Image
# filepaths
fp_in = "images/*.png"
fp_out = "result.gif"
stop_while = 5
# https://pillow.readthedocs.io/en/stable/handbook/image-file-formats.html#gif
sorted_images = sorted(glob.glob(fp_in))

for i in range(5):
  sorted_images.append(sorted_images[-1])

img, *imgs = [Image.open(f).resize((320, 320), Image.NEAREST) for f in (sorted_images)]
img.save(fp=fp_out, format='GIF', append_images=imgs,
         save_all=True, duration=500, loop=0)

from IPython.display import Image, display
with open(fp_out,'rb') as f:
    display(Image(data=f.read(), format='png'))
# Out:
# /tmp/ipykernel_15609/1133801733.py:13: DeprecationWarning: NEAREST is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.NEAREST or Dither.NONE instead.
#   img, *imgs = [Image.open(f).resize((320, 320), Image.NEAREST) for f in (sorted_images)]
